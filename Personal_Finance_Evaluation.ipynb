# %% [markdown]
# <a href="https://colab.research.google.com/github/eilyn0208/MA1042/blob/google-colab/Personal_Finance_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('finaldata.xlsx')

# %%
df.shape[0]
# Out:
# 120

# %%
df["Budget"].min(), df["Budget"].max()
# Out:
# (50, 8000)

# %%
df.loc[df["Budget"].idxmin()]
# Out:
# Number                                        9
# Date (dd/mm/yy)             2026-05-01 00:00:00
# Name of the activity    savings account deposit
# Cost                                         50
# Budget                                       50
# Time invested                                40
# Type                                          2
# Moment                                        2
# No. of people                                 1
# Name: 8, dtype: object

# %%
df.loc[df["Budget"].idxmax()]
# Out:
# Number                                   20
# Date (dd/mm/yy)         2026-08-01 00:00:00
# Name of the activity        attending class
# Cost                                   5000
# Budget                                 8000
# Time invested                           240
# Type                                      5
# Moment                                    1
# No. of people                             1
# Name: 19, dtype: object

# %%
df.groupby("Type")["Cost"].sum()
# Out:
# Type
# 1     9750
# 2     2550
# 3     3530
# 4    14010
# 5    37660
# 6      240
# Name: Cost, dtype: int64

# %%
df["Date (dd/mm/yy)"].nunique()
# Out:
# 26

# %%
df["Cost"].sum()
# Out:
# np.int64(67740)

# %%
df.loc[df["Type"] == 2, "Cost"].sum()
# Out:
# np.int64(2550)

# %%
avg_daily_savings = df.loc[df["Type"] == 2, "Cost"].mean()

# %%
wishlist_price = 2000

# %%
wishlist_price / avg_daily_savings
# Out:
# np.float64(3.9215686274509802)
